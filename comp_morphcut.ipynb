# %% [markdown]
# Env setup

# %%
# !git clone https://github.com/eiiijiiiy/SAMPart3D
# !pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install -r SAMPart3D/requirements.txt

import sys
sys.path.append('./SAMPart3D')
# Out:
# fatal: destination path 'SAMPart3D' already exists and is not an empty directory.
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 109.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 11.6 MB/s eta 0:00:00
# ...

# %%
import os
from setuptools import setup
from torch.utils.cpp_extension import BuildExtension, CUDAExtension
from distutils.sysconfig import get_config_vars

# %%
# %cd SAMPart3D/libs/pointops
# !ls
# !python3 setup.py install
# Out:
# build  dist  functions	__init__.py  pointops.egg-info	setup.py  src
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/content/SAMPart3D/libs/pointops/setup.py", line 3, in <module>
#     from torch.utils.cpp_extension import BuildExtension, CUDAExtension
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
# ...

# %%
# !pip install spconv-cu121
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/pointops-1.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.3/76.3 MB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 31.7 MB/s eta 0:00:00
# ...

# %%
# !pip install ninja git+https://github.com/NVlabs/tiny-cuda-nn/#subdirectory=bindings/torch
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/pointops-1.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#   Cloning https://github.com/NVlabs/tiny-cuda-nn/ to /tmp/pip-req-build-_f2mvxr1
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/tiny-cuda-nn/ /tmp/pip-req-build-_f2mvxr1
#   Resolved https://github.com/NVlabs/tiny-cuda-nn/ to commit 075158a70b87dba8729188a9cadc9411cfa4b71d
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tinycudann: filename=tinycudann-1.7-cp311-cp311-linux_x86_64.whl size=29858181 sha256=ecf03e77ae746dcdd86a5c8b8c18814ef0dd5c38a84c333aa64ed4d23f0946b6
# ...

# %%
# !pip install \
    --extra-index-url=https://pypi.nvidia.com \
    "cudf-cu12==25.2.*" "cuml-cu12==25.2.*"
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/pointops-1.0-py3.11-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# ...

# %% [markdown]
# # New Section

# %%
# !wget https://download.blender.org/release/Blender4.0/blender-4.0.0-linux-x64.tar.xz
# !tar -xf blender-4.0.0-linux-x64.tar.xz
# !rm blender-4.0.0-linux-x64.tar.xz
# Out:
# --2025-04-03 08:52:43--  https://download.blender.org/release/Blender4.0/blender-4.0.0-linux-x64.tar.xz
# Resolving download.blender.org (download.blender.org)... 172.67.14.163, 104.22.65.163, 104.22.64.163, ...
# Connecting to download.blender.org (download.blender.org)|172.67.14.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 277532952 (265M) [application/octet-stream]
# Saving to: ‘blender-4.0.0-linux-x64.tar.xz’
#
# blender-4.0.0-linux 100%[===================>] 264.68M   246MB/s    in 1.1s
#
# 2025-04-03 08:52:44 (246 MB/s) - ‘blender-4.0.0-linux-x64.tar.xz’ saved [277532952/277532952]

# %%
# !git clone https://huggingface.co/yhyang-myron/SAMPart3D model_data
# Out:
# Cloning into 'model_data'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 13 (delta 1), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (13/13), 128.28 KiB | 6.41 MiB/s, done.

# %%
# !ls
# !./../blender-4.0.0-linux-x64/blender -b -P blender_render_16views.py /content/SAMPart3D/model_data/knight.glb glb /content/SAMPart3D/model_data/knight
# Out:
# blender_render_16views.py  highlight_parts.py
# Blender 4.0.0 (hash 878f71061b8e built 2023-11-14 00:52:48)
# Data are loaded, start creating Blender stuff
# glTF import finished in 0.02s
# GHOST/Wayland: error: XDG_RUNTIME_DIR not set in the environment.
# ./../blender-4.0.0-linux-x64/blender() [0xf3a6f0]
# /lib/x86_64-linux-gnu/libwayland-client.so.0(+0x595a) [0xf2c8e2fe95a]
# /lib/x86_64-linux-gnu/libwayland-client.so.0(wl_display_connect+0x26c) [0xf2c8e3032bc]
# ./../blender-4.0.0-linux-x64/blender() [0x27c39ba]
# ./../blender-4.0.0-linux-x64/blender() [0x27aea9e]
# ./../blender-4.0.0-linux-x64/blender() [0x27aebcc]
# ./../blender-4.0.0-linux-x64/blender() [0x27ad159]
# ./../blender-4.0.0-linux-x64/blender() [0xf79375]
# ./../blender-4.0.0-linux-x64/blender() [0xf61be5]
# ./../blender-4.0.0-linux-x64/blender() [0x111fa15]
# ./../blender-4.0.0-linux-x64/blender() [0x1ceebf9]
# ./../blender-4.0.0-linux-x64/blender() [0x1cef697]
# ./../blender-4.0.0-linux-x64/blender() [0x1cf39a4]
# ...

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !sh scripts/eval.sh -g 1 -d sampart3d -n knight -w 5000
# Out:
# Experiment name: knight
# Python interpreter dir: python
# Dataset: sampart3d
# GPU Num: 1
# Loading config in: exp/sampart3d/knight/config.py
# Running code in: exp/sampart3d/knight/code
#  =========> RUN TASK <=========
# Traceback (most recent call last):
#   File "/content/SAMPart3D/launch/eval.py", line 1, in <module>
#     from pointcept.engines.defaults import (
# ModuleNotFoundError: No module named 'pointcept'
